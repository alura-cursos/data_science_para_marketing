# %%
2 + 2
# Out:
# 4

# %%
3 * 4
# Out:
# 12

# %%
120 / 6
# Out:
# 20.0

# %%
nome = "Dani"

# %%
print(nome)
# Out:
# Dani

# %%
idade = 35
idade
# Out:
# 35

# %%
formacao = "Marketing"

# %%
curso = "Data Science para Marketing"

# %%
print(f"Olá, {nome}! Notamos que você é formado em {formacao}. Bem vindo(a) ao curso de {curso}.")
# Out:
# Olá, Dani! Notamos que você é formado em Marketing. Bem vindo(a) ao curso de Data Science para Marketing.

# %% [markdown]
# # Analisando o arquivo de campanha

# %%
import pandas as pd

# %%
campanha = pd.read_csv("/content/campanha.csv")

# %%
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado    pais
# 0            1      152431     9462       Email  13258    32309     MG  Brasil
# 1            1       39688     3218         PPC  16391    16568     BA  Brasil
# 2            1      104506     4756  Google Ads   6189    19029     AL  Brasil
# 3            1       80768     3566  Google Ads   5215        0     PI  Brasil
# 4            1       54932     3645  Google Ads  16767     8825     RJ  Brasil

# %%
campanha.shape
# Out:
# (50000, 8)

# %%
campanha['canal']
# Out:
# 0               Email
# 1                 PPC
# 2          Google Ads
# 3          Google Ads
# 4          Google Ads
#              ...
# 49995    Social Media
# 49996      Google Ads
# 49997      Google Ads
# 49998             PPC
# 49999        Meta Ads
# Name: canal, Length: 50000, dtype: object

# %%
campanha['canal'].unique()
# Out:
# array(['Email', 'PPC', 'Google Ads', 'Meta Ads', 'Social Media'],
#       dtype=object)

# %%
campanha['canal'].value_counts()
# Out:
# canal
# Google Ads      25146
# Meta Ads        15009
# Social Media     4874
# PPC              2526
# Email            2445
# Name: count, dtype: int64

# %% [markdown]
# CTR = (cliques / impressoes) * 100

# %%
campanha['ctr'] = (campanha['cliques']/campanha['impressoes']) * 100

# %%
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado  \
# 0            1      152431     9462       Email  13258    32309     MG
# 1            1       39688     3218         PPC  16391    16568     BA
# 2            1      104506     4756  Google Ads   6189    19029     AL
# 3            1       80768     3566  Google Ads   5215        0     PI
# 4            1       54932     3645  Google Ads  16767     8825     RJ
#
#      pais       ctr
# 0  Brasil  6.207399
# 1  Brasil  8.108244
# 2  Brasil  4.550935
# 3  Brasil  4.415115
# 4  Brasil  6.635477

# %%
campanha['ctr'].plot()
# Out:
# <Axes: >

# %%
campanha['ctr'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
campanha['ctr'].describe()
# Out:
# count    50000.000000
# mean         5.148482
# std          1.604119
# min          0.992663
# 25%          4.050781
# 50%          5.132384
# 75%          6.241502
# max         10.000000
# Name: ctr, dtype: float64

# %%
campanha['ctr'].median()
# Out:
# 5.132384085295483

# %%
campanha['ctr'].mean()
# Out:
# 5.1484815905088634

# %%
import seaborn as sns

# %%
sns.boxplot(campanha['ctr'])
# Out:
# <Axes: ylabel='ctr'>

# %%
campanha.query('Id_campanha == 1')
# Out:
#     Id_campanha  impressoes  cliques         canal  custo  receita estado  \
# 0             1      152431     9462         Email  13258    32309     MG
# 1             1       39688     3218           PPC  16391    16568     BA
# 2             1      104506     4756    Google Ads   6189    19029     AL
# 3             1       80768     3566    Google Ads   5215        0     PI
# 4             1       54932     3645    Google Ads  16767     8825     RJ
# 5             1       86472     3266    Google Ads  15870    12483     BA
# 6             1       63460     4869      Meta Ads  13769    10849     SP
# 7             1       45206     2231      Meta Ads  26270     8583     MA
# 8             1       85974     5340    Google Ads  42535       91     PE
# 9             1      128497     4717      Meta Ads  10310    19235     MS
# 10            1      103955     5454         Email  17591    29256     SP
# 11            1       82063     5585  Social Media   9910    12884     DF
# ...

# %%
campanha.query('Id_campanha == 1').mean(numeric_only=True)
# Out:
# Id_campanha        1.000000
# impressoes     96580.806452
# cliques         4902.096774
# custo          13863.419355
# receita        14000.806452
# ctr                5.210398
# dtype: float64

# %%
campanha.query('Id_campanha == 1')['impressoes']
# Out:
# 0     152431
# 1      39688
# 2     104506
# 3      80768
# 4      54932
# 5      86472
# 6      63460
# 7      45206
# 8      85974
# 9     128497
# 10    103955
# 11     82063
# 12    122904
# 13     87811
# 14    135775
# 15    118325
# 16    152660
# 17     32584
# 18     96197
# 19     92587
# 20    131817
# 21    140411
# 22    111975
# 23    121385
# 24     87129
# 25     71381
# 26    159400
# 27       100
# 28    117185
# 29    118326
# 30     68101
# Name: impressoes, dtype: int64

# %%
campanha.query('Id_campanha == 1')['impressoes'].mean()
# Out:
# 96580.80645161291

# %%
campanha.groupby('Id_campanha')['impressoes']

# %%
medias_por_campanha = campanha.groupby('Id_campanha')['impressoes'].mean()
medias_por_campanha.head()
# Out:
# Id_campanha
# 1     96580.806452
# 2     92372.923077
# 3    118489.333333
# 4     96947.681818
# 5    105508.291667
# Name: impressoes, dtype: float64

# %%
medias_por_campanha.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
metricas_por_tipo = campanha.groupby('canal')['ctr'].mean()
metricas_por_tipo
# Out:
# canal
# Email           5.109386
# Google Ads      5.152163
# Meta Ads        5.133841
# PPC             5.162208
# Social Media    5.187068
# Name: ctr, dtype: float64

# %%
sns.boxplot(medias_por_campanha)
# Out:
# <Axes: ylabel='impressoes'>

# %%
medias_por_campanha.describe()
# Out:
# count      2000.000000
# mean      99924.847399
# std        7651.690148
# min       74315.388889
# 25%       94601.752717
# 50%       99731.860577
# 75%      105173.546176
# max      124154.071429
# Name: impressoes, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.displot(medias_por_campanha, kde = True)
plt.title('Histograma das médias das campanhas')
plt.show()

# %%
sns.displot(campanha['receita'])
plt.title('Distribuição da receita das campanhas')
plt.show()

# %%
# prompt: gráfico de distribuição do custo da campanha

import matplotlib.pyplot as plt
sns.displot(campanha['custo'])
plt.title('Distribuição do custo das campanhas')
plt.show()

# %%
campanha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_campanha  50000 non-null  int64
#  1   impressoes   50000 non-null  int64
#  2   cliques      50000 non-null  int64
#  3   canal        50000 non-null  object
#  4   custo        50000 non-null  int64
#  5   receita      50000 non-null  int64
#  6   estado       50000 non-null  object
#  7   pais         50000 non-null  object
#  8   ctr          50000 non-null  float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 3.4+ MB

# %%
campanha.describe()
# Out:
#         Id_campanha     impressoes      cliques         custo        receita  \
# count  50000.000000   50000.000000  50000.00000  50000.000000   50000.000000
# mean    1004.637160   99916.792660   5146.89304  14478.263920   14242.518860
# std      578.014356   38217.517352   2612.96365   6072.944902   10365.240991
# min        1.000000     100.000000      1.00000   2723.000000       0.000000
# 25%      504.000000   72238.000000   3209.00000  10164.000000    7757.000000
# 50%     1007.000000   99951.500000   4829.00000  13348.000000   11855.500000
# 75%     1506.000000  127436.000000   6741.25000  17513.000000   18070.250000
# max     2000.000000  200000.000000  19484.00000  80000.000000  134842.000000
#
#                 ctr
# count  50000.000000
# mean       5.148482
# std        1.604119
# min        0.992663
# 25%        4.050781
# 50%        5.132384
# 75%        6.241502
# max       10.000000

# %%
campanha['estado']
# Out:
# 0        MG
# 1        BA
# 2        AL
# 3        PI
# 4        RJ
#          ..
# 49995    MG
# 49996    MA
# 49997    RS
# 49998    DF
# 49999    RJ
# Name: estado, Length: 50000, dtype: object

# %%
campanha['estado'].unique()
# Out:
# array(['MG', 'BA', 'AL', 'PI', 'RJ', 'SP', 'MA', 'PE', 'MS', 'DF', 'CE',
#        'AM', 'SE', 'PA', 'PR', 'SC', 'GO', 'RN', 'RO', 'ES', 'MT', 'TO',
#        'PB', 'RS', 'AC', 'AP', 'RR'], dtype=object)

# %%
campanha['estado'].value_counts()
# Out:
# estado
# SP    11006
# MG     4902
# RJ     4221
# BA     3524
# RS     2701
# PR     2698
# PE     2255
# CE     2140
# PA     2024
# SC     1741
# GO     1715
# MA     1643
# AM      959
# PB      952
# ES      927
# MT      839
# RN      823
# PI      784
# AL      784
# DF      714
# MS      674
# SE      586
# RO      445
# TO      345
# AC      226
# AP      217
# RR      155
# Name: count, dtype: int64

# %%
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado  \
# 0            1      152431     9462       Email  13258    32309     MG
# 1            1       39688     3218         PPC  16391    16568     BA
# 2            1      104506     4756  Google Ads   6189    19029     AL
# 3            1       80768     3566  Google Ads   5215        0     PI
# 4            1       54932     3645  Google Ads  16767     8825     RJ
#
#      pais       ctr
# 0  Brasil  6.207399
# 1  Brasil  8.108244
# 2  Brasil  4.550935
# 3  Brasil  4.415115
# 4  Brasil  6.635477

# %%
campanha['estado'].value_counts().index
# Out:
# Index(['SP', 'MG', 'RJ', 'BA', 'RS', 'PR', 'PE', 'CE', 'PA', 'SC', 'GO', 'MA',
#        'AM', 'PB', 'ES', 'MT', 'RN', 'PI', 'AL', 'DF', 'MS', 'SE', 'RO', 'TO',
#        'AC', 'AP', 'RR'],
#       dtype='object', name='estado')

# %%
campanha['estado'].value_counts().values
# Out:
# array([11006,  4902,  4221,  3524,  2701,  2698,  2255,  2140,  2024,
#         1741,  1715,  1643,   959,   952,   927,   839,   823,   784,
#          784,   714,   674,   586,   445,   345,   226,   217,   155])

# %%
campanha['estado'].value_counts().to_frame()
# Out:
#         count
# estado
# SP      11006
# MG       4902
# RJ       4221
# BA       3524
# RS       2701
# PR       2698
# PE       2255
# CE       2140
# PA       2024
# SC       1741
# GO       1715
# MA       1643
# AM        959
# PB        952
# ES        927
# MT        839
# RN        823
# PI        784
# AL        784
# DF        714
# MS        674
# SE        586
# RO        445
# TO        345
# AC        226
# AP        217
# RR        155

# %%
contagem_de_estados = campanha['estado'].value_counts().to_frame().reset_index()

# %%
contagem_de_estados.columns = ['estado', 'total']

# %%
contagem_de_estados.head()
# Out:
#   estado  total
# 0     SP  11006
# 1     MG   4902
# 2     RJ   4221
# 3     BA   3524
# 4     RS   2701

# %%
contagem_de_estados.plot()
# Out:
# <Axes: >

# %%
sns.barplot(data=contagem_de_estados, x='estado', y='total')
# Out:
# <Axes: xlabel='estado', ylabel='total'>

# %%
sns.countplot(data=campanha, x='estado')
# Out:
# <Axes: xlabel='estado', ylabel='count'>

# %%
contagem_de_estados.plot(kind='pie', y='total')
# Out:
# <Axes: ylabel='total'>

# %%
contagem_de_estados.plot(kind='pie', y='total', labels= contagem_de_estados['estado'])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_estado = campanha['estado'].value_counts()
total_geral = total_por_estado.sum()
total_em_SP = total_por_estado.loc['SP']
total_do_restante = total_geral - total_em_SP
print(total_geral, total_em_SP, total_do_restante)
# Out:
# 50000 11006 38994

# %%
dados = {
    'estado' : ['SP', 'outros'],
    'total': [total_em_SP, total_do_restante]
}
dados = pd.DataFrame(dados)
dados.head()
# Out:
#    estado  total
# 0      SP  11006
# 1  outros  38994

# %%
dados.plot(kind='pie', y='total', labels=dados['estado'])
# Out:
# <Axes: ylabel='total'>

# %%
total_de_outros_estados = campanha.query('estado != "SP"')['estado'].value_counts()
total_de_outros_estados.head()
# Out:
# estado
# MG    4902
# RJ    4221
# BA    3524
# RS    2701
# PR    2698
# Name: count, dtype: int64

# %%
sns.countplot(data=campanha.query('estado != "SP"'),
              order=total_de_outros_estados.index,
              palette = 'mako',
              hue='estado',
              stat = 'percent',
              x='estado')
plt.title('Distribuição das campanhas nos estados exceto em SP')
plt.show()

# %%
campanha['roi'] = (campanha['receita'] - campanha['custo']) / campanha['custo']
campanha.head()
# Out:
#    Id_campanha  impressoes  cliques       canal  custo  receita estado  \
# 0            1      152431     9462       Email  13258    32309     MG
# 1            1       39688     3218         PPC  16391    16568     BA
# 2            1      104506     4756  Google Ads   6189    19029     AL
# 3            1       80768     3566  Google Ads   5215        0     PI
# 4            1       54932     3645  Google Ads  16767     8825     RJ
#
#      pais       ctr       roi
# 0  Brasil  6.207399  1.436944
# 1  Brasil  8.108244  0.010799
# 2  Brasil  4.550935  2.074649
# 3  Brasil  4.415115 -1.000000
# 4  Brasil  6.635477 -0.473669

# %%
sns.displot(campanha['roi'])
plt.title('Distribuição do roi das campanhas')
plt.show()

# %%
metricas_google_ads = campanha.query('canal == "Google Ads"')
metricas_email = campanha.query('canal == "Email"')

media_metricas_google_ads = metricas_google_ads['roi'].mean()
media_metricas_email = metricas_email['roi'].mean()

print(media_metricas_google_ads, media_metricas_email)
# Out:
# 0.13674573394615885 0.16903111529695838

# %%
[
    20000,
    20000,
    20000,
    20000,
    20000,
    20000,
    20000,
    20000,
    20000,
    20000,
    30000,
    30000,
    30000,
    30000,
    30000,
    30000,
    30000,
    30000,
    30000,
    30000
    ]
# Out:
# [20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  20000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000,
#  30000]

# %%
google_ads = [20000] * 10 + [30000] * 10
mean(google_ads)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-da7007b0a6a0> in <cell line: 2>()
#       1 google_ads = [20000] * 10 + [30000] * 10
# ----> 2 mean(google_ads)
#
# NameError: name 'mean' is not defined

# %%
import numpy as np

google_ads = [20000] * 10 + [30000] * 10
np.mean(google_ads)
# Out:
# 25000.0

# %%
meta_ads = [40000] * 10 + [10000] * 10
np.mean(meta_ads)
# Out:
# 25000.0

# %%
# prompt: Imprima a média e a mediana do google_ads e do meta_ads

import numpy as np
print(f"Média do google_ads: {np.mean(google_ads)}")
print(f"Mediana do google_ads: {np.median(google_ads)}")
print(f"Média do meta_ads: {np.mean(meta_ads)}")
print(f"Mediana do meta_ads: {np.median(meta_ads)}")
# Out:
# Média do google_ads: 25000.0
# Mediana do google_ads: 25000.0
# Média do meta_ads: 25000.0
# Mediana do meta_ads: 25000.0

# %%
campanha0 = [25000] * 20
np.mean(campanha0)
# Out:
# 25000.0

# %%
np.std(campanha0), np.std(google_ads), np.std(meta_ads)
# Out:
# (0.0, 5000.0, 15000.0)

# %%
plt.boxplot([metricas_google_ads['roi'], metricas_email['roi']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c1aa3d1b580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c1aa3d18370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c1aa3d1bcd0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7c1aa39992d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7c1aa3999f00>,
# ...
#  'means': []}

# %%
sns.boxplot(data=campanha.query('canal in ["Google Ads", "Email"]'),
            x= 'canal',
            y= 'roi')
# Out:
# <Axes: xlabel='canal', ylabel='roi'>

# %%
# prompt: mesmo gráfico mas colorido

sns.boxplot(data=campanha.query('canal in ["Google Ads", "Email"]'),
            x= 'canal',
            y= 'roi', palette='Set2')
# Out:
# <ipython-input-85-db93b5f3fc41>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=campanha.query('canal in ["Google Ads", "Email"]'),
# <Axes: xlabel='canal', ylabel='roi'>
